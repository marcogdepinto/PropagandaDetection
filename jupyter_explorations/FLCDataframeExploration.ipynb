# %%
import pandas as pd

df = pd.read_pickle('./pickled/train_set_FLC.pkl')

# %%
df.head(100)
# Out:
#    article_id  start_index  end_index  \
# 0   780619695         1538       1554
# 1   780619695         1728       1744
# 2   780619695         2018       2034
# 3   780619695         2245       2261
# 4   780619695         2838       2854
# 5   780619695         3066       3082
# 6   780619695           44         62
# 7   780619695         3735       3740
# 8   780619695         6301       6314
# 9   780619695         1321       1337
# 10  780619695         1935       1959
# 11  780619695         4123       4129
# 12  780619695          137        148
# 13  780619695          149        160
# 14  780619695          162        168
# 15  780619695          174        183
# 16  780619695          120        136
# 17  780619695         1245       1262
# 18  780619695         1770       1794
# 19  780619695         2318       2325
# 20  780619695         2329       2338
# 21  780619695         2343       2359
# 22  780619695         3207       3224
# ...

# %%
df.technique.unique() # Classes to predict
# Out:
# array(['Repetition', 'Slogans', 'Loaded_Language',
#        'Exaggeration,Minimisation', 'Name_Calling,Labeling',
#        'Appeal_to_fear-prejudice', 'Reductio_ad_hitlerum', 'Doubt',
#        'Appeal_to_Authority', 'Black-and-White_Fallacy', 'Flag-Waving',
#        'Causal_Oversimplification', 'Whataboutism',
#        'Thought-terminating_Cliches',
#        'Obfuscation,Intentional_Vagueness,Confusion', 'Bandwagon',
#        'Red_Herring', 'Straw_Men'], dtype=object)

# %%
df2 = pd.read_pickle('./pickled/train_set_SLC.pkl')

# %%
df2.head(100)
# Out:
#    article_id  line   is_propaganda  \
# 0   761874505     1  non-propaganda
# 1   761874505     2  non-propaganda
# 2   761874505     3  non-propaganda
# 3   761874505     4  non-propaganda
# 4   761874505     5  non-propaganda
# 5   761874505     6  non-propaganda
# 6   761874505     7  non-propaganda
# 7   761874505     8  non-propaganda
# 8   761874505     9  non-propaganda
# 9   761874505    10  non-propaganda
# 10  761874505    11  non-propaganda
# 11  761874505    12      propaganda
# 12  761874505    13  non-propaganda
# 13  761874505    14      propaganda
# 14  761874505    15  non-propaganda
# 15  761874505    16  non-propaganda
# 16  761874505    17      propaganda
# 17  761874505    18      propaganda
# 18  761874505    19  non-propaganda
# 19  761874505    20      propaganda
# 20  761874505    21      propaganda
# 21  761874505    22      propaganda
# 22  729561658     1      propaganda
# 23  729561658     2  non-propaganda
# 24  729561658     3  non-propaganda
# ...
